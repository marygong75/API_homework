# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import json_normalize

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-66-4b2c9a94b46f> in <module>()
#       6 import time
#       7 import json
# ----> 8 import json_normalize
#       9
#      10 # Import API key
#
# ModuleNotFoundError: No module named 'json_normalize'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API calls
url = "http://api.openweathermap.org/data/2.5/find?lat=55.5&lon=37.5&cnt=10&APPID=aa7c6649faace9476f1f63219f1a841a"

#query = "lat=55.5&lon=37.5&cnt=10&AAPID="

#http://api.openweathermap.org/data/2.5/find?lat=55.5&lon=37.5&cnt=10&APPID=aa7c6649faace9476f1f63219f1a841a

# Build query URL
#query_url = url + query + api_keys
#query_url = f"{url}{query}{api_keys}"

weather = requests.get(url).json()

# %%
#pretty up the output of JSON
print(json.dumps(weather, indent=4, sort_keys=True))
# Out:
# {
#     "cod": "200",
#     "count": 10,
#     "list": [
#         {
#             "clouds": {
#                 "all": 75
#             },
#             "coord": {
#                 "lat": 55.4997,
#                 "lon": 37.5597
#             },
#             "dt": 1544486400,
#             "id": 495260,
#             "main": {
#                 "humidity": 96,
#                 "pressure": 1008,
#                 "temp": 273.41,
#                 "temp_max": 274.15,
#                 "temp_min": 273.15
#             },
#             "name": "Shcherbinka",
#             "rain": null,
#             "snow": null,
#             "sys": {
#                 "country": ""
#             },
#             "weather": [
#                 {
#                     "description": "shower snow",
#                     "icon": "13n",
#                     "id": 621,
#                     "main": "Snow"
#                 },
#                 {
#                     "description": "mist",
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Loop through the list of cities and perform a request for data on each
#for city in cities:
#    response = requests.get(query_url + city).json()
 #   lat.append(response['coord']['lat'])
#    temp.append(response['main']['temp'])

#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {temp}")

# %%
weather
# Out:
# {'message': 'accurate',
#  'cod': '200',
#  'count': 10,
#  'list': [{'id': 495260,
#    'name': 'Shcherbinka',
#    'coord': {'lat': 55.4997, 'lon': 37.5597},
#    'main': {'temp': 273.41,
#     'pressure': 1008,
#     'humidity': 96,
#     'temp_min': 273.15,
#     'temp_max': 274.15},
#    'dt': 1544486400,
#    'wind': {'speed': 3, 'deg': 120},
#    'sys': {'country': ''},
#    'rain': None,
#    'snow': None,
#    'clouds': {'all': 75},
#    'weather': [{'id': 621,
#      'main': 'Snow',
#      'description': 'shower snow',
#      'icon': '13n'},
#     {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}]},
#   {'id': 564517,
#    'name': 'Dubrovitsy',
#    'coord': {'lat': 55.4397, 'lon': 37.4867},
#    'main': {'temp': 273.41,
#     'pressure': 1008,
#     'humidity': 96,
#     'temp_min': 273.15,
#     'temp_max': 274.15},
#    'dt': 1544486400,
#    'wind': {'speed': 3, 'deg': 120},
#    'sys': {'country': ''},
#    'rain': None,
#    'snow': None,
# ...

# %%
#from pandas.io.json import json_normalize
#df = pd.DataFrame.from_dict(weather{list}, orient='columns')
#df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-191c902d9720> in <module>()
#       3 #df
#       4 pd.DataFrame(weather)
# ----> 5 df.to_csv(file_name)
#
# NameError: name 'file_name' is not defined

# %%
#Create data frame from cities
pd.DataFrame(weather)
# Out:
#     message  cod  count                                               list
# 0  accurate  200     10  {'id': 495260, 'name': 'Shcherbinka', 'coord':...
# 1  accurate  200     10  {'id': 564517, 'name': 'Dubrovitsy', 'coord': ...
# 2  accurate  200     10  {'id': 570578, 'name': 'Butovo', 'coord': {'la...
# 3  accurate  200     10  {'id': 545782, 'name': 'Kommunarka', 'coord': ...
# 4  accurate  200     10  {'id': 6417490, 'name': 'Lesparkkhoz', 'coord'...
# 5  accurate  200     10  {'id': 526736, 'name': 'Sed’moy Mikrorayon', '...
# 6  accurate  200     10  {'id': 473051, 'name': 'Vlas’yevo', 'coord': {...
# 7  accurate  200     10  {'id': 578680, 'name': 'Bachurino', 'coord': {...
# 8  accurate  200     10  {'id': 554629, 'name': 'Shestoy Mikrorayon', '...
# 9  accurate  200     10  {'id': 508101, 'name': 'Podolsk', 'coord': {'l...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
